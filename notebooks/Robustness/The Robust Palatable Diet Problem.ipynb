# %% [markdown]
# # The Palatable Diet Problem
#
# **Problem Description.** The Diet Problem is the first large-scale optimization problem to be solved with the Simplex algorithm by Jack Laderman in [1947](https://www.mpi-inf.mpg.de/fileadmin/inf/d1/teaching/winter18/Ideen/Materialien/Dantzig-Diet.pdf). The basic formulation of this problem consists of minimizing the cost of a food basket while meeting the specified nutrient requirements. In this notebook, we solve The Palatable Diet Problem (TPDP), where the basic model is extended with a constraint on the food basket palatability. An explicit formula of the palatability constraint is unknown, but we have data on several food baskets and the respective palatability score. First, we define a conceptual model with the *known constraint*. Then, OptiCL is used to learn and embed the palatability constraint.
# (*TPDP is part of a larger optimization problem which simultaneously  optimizes  the  food  basket  to  be  delivered,  the  sourcing  plan,  the  delivery  plan, and  the  transfer  modality  of  a  month-long  food  supply in a Wolrd Food Program setting ([Maragno et al., 2021])*).
#
# <font color='#808080'>**Objective function:** minimize the total cost of the food basket.</font>
# $\min_{\boldsymbol{x}} c^\top \boldsymbol{x}$
#
# *subject to*
#
# <font color='#808080'>**Nutritional constraints:** for each nutrient $l\in\mathcal{L}$, at least meet the minimum required level.</font>
# $ \sum_{k \in \mathcal{K}} nutval_{kl} x_{k} \geq nutreq_{l}, \ \ \ \forall l\in\mathcal{L},$
# <font color='#808080'>**Constraints on sugar and salt.**</font>
# $ x_{salt} = 5,$
# $ x_{sugar} = 20,$
# <font color='#808080'>**Palatability constraints:** the food basket palatability has to be at least equal to $t$.</font>
# $ y \geq t,$
# <font color='#808080'>**Learned predictive model:** the palatability is defined using a predictive model.</font>
# $ y = \hat{h}(\boldsymbol{x}),$
# <font color='#808080'>**Non negativity constraints.**</font>
# $ x_{k} \geq 0, \ \ \ \forall k \in \mathcal{K}.$

# %%
import pandas as pd
from imp import reload
import numpy as np
import math
from sklearn.utils.extmath import cartesian
import time
import sys
import os
sys.path.append(os.path.abspath('../../src'))  # TODO: has to be changed
import opticl
from pyomo import environ
from pyomo.environ import *
np.random.seed(0)

# %% [markdown]
# ### Data Loading
# **nutr_val**: nutritional values for each of the 25 foods
# **nutr_req**: 11 nutrition requirements
# **cost_p**: vector of procurement costs
# **dataset**: dataframe of food basket instances and relative palatability score

# %%
nutr_req
# Out:
#                 Energy(kcal)  Protein(g)  Fat(g)  Calcium(mg)  Iron(mg)  \
# Type
# Avg person day          2100        52.5      35         1100        22
#
#                 VitaminA(ug)  ThiamineB1(mg)  RiboflavinB2(mg)  NicacinB3(mg)  \
# Type
# Avg person day           500             0.9               1.4             12
#
#                 Folate(ug)  VitaminC(mg)  Iodine(ug)
# Type
# Avg person day         160            28         150

# %%
nutr_val = pd.read_excel('processed-data/Syria_instance.xlsx', sheet_name='nutr_val', index_col='Food')
nutr_req = pd.read_excel('processed-data/Syria_instance.xlsx', sheet_name='nutr_req', index_col='Type')
cost_p = pd.read_excel('processed-data/Syria_instance.xlsx', sheet_name='FoodCost', index_col='Supplier').iloc[0,:]
dataset = pd.read_csv('processed-data/WFP_dataset.csv').sample(frac=1)

nutr_val.drop(['Salt','Sugar'], axis=0, inplace = True)
nutr_val.drop(['Iodine(ug)'], axis=1, inplace = True)
nutr_req.drop(['Iodine(ug)'], axis=1, inplace = True)
dataset.drop(['Salt','Sugar'], axis=1, inplace=True)

# %%
def normalize(y):
    minimum = 71.969  
    maximum = 444.847  
    return 1 - (y - minimum)/(maximum - minimum)

def check_violation(threshold, solution):
    # Cereals & Grains
    group1 = [1, 11, 12, 14, 15, 22, 23]
    group1_names = [list(solution.keys())[i] for i in group1]
    values1 = [solution[x] for x in group1_names]
    food_in_group1 = sum(values1)*100
#     print(f'food_in_group1 {food_in_group1}')
    idealG1 = 400
    distG1 = food_in_group1 - idealG1
    
    # Pulses & Vegetables
    group2 = [0, 6, 10, 13]
    group2_names = [list(solution.keys())[i] for i in group2]
    values2 = [solution[x] for x in group2_names]
    food_in_group2 = sum(values2)*100
#     print(f'food_in_group2 {food_in_group2}')
    idealG2 = 65
    distG2 = food_in_group2 - idealG2
    
    # Oils & Fats
    group3 = [21]
    group3_names = [list(solution.keys())[i] for i in group3]
    values3 = [solution[x] for x in group3_names]
    food_in_group3 = sum(values3)*100
#     print(f'food_in_group3 {food_in_group3}')
    idealG3 = 27
    distG3 = food_in_group3 - idealG3
    
    # Mixed & Blended Foods
    group4 = [5, 24, 16, 17, 18, 19]
    group4_names = [list(solution.keys())[i] for i in group4]
    values4 = [solution[x] for x in group4_names]
    food_in_group4 = sum(values4)*100
#     print(f'food_in_group4 {food_in_group4}')
    idealG4 = 45
    distG4 = food_in_group4 - idealG4
    
    # Meat & Fish & Dairy
    group5 = [2, 3, 4, 7, 8]
    group5_names = [list(solution.keys())[i] for i in group5]
    values5 = [solution[x] for x in group5_names]
    food_in_group5 = sum(values5)*100
#     print(f'food_in_group5 {food_in_group5}')
    idealG5 = 30
    distG5 = food_in_group5 - idealG5
    
    real_palatability = np.round(math.sqrt(distG1 ** 2 + (5.7 * distG2) ** 2 + (16.6 * distG3) ** 2
                                      + (4.4 * distG4) ** 2 + (6.6 * distG5) ** 2), 3)
    real_palatability_norm = normalize(real_palatability)
    
    return 1-int(real_palatability_norm>=threshold), real_palatability_norm

# %% [markdown]
# # OptiCL: Optimization with Constraint Learning

# %% [markdown]
# ## Step 1: Conceptual Model

# %%
def init_conceptual_model(cost_p):
    N = list(nutr_val.index)  # foods
    M = nutr_req.columns  # nutrient requirements

    model = ConcreteModel('TPDP')

    '''
    Decision variables
    '''
    model.x = Var(N, domain=NonNegativeReals)  # variables controlling the food basket

    '''
    Objective function.
    '''
    def obj_function(model):
        return sum(cost_p[food].item()*model.x[food] for food in N)

    model.OBJ = Objective(rule=obj_function, sense=minimize)

    '''
    Nutrients requirements constraint.
    '''
    def constraint_rule1(model, req):
        return sum(model.x[food] * nutr_val.loc[food, req] for food in N) >= nutr_req[req].item()
    model.Constraint1 = Constraint(M, rule=constraint_rule1)
    '''
    Sugar constraint
    '''
#     def constraint_rule2(model):
#         return model.x['Sugar'] == 0.2
#     model.Constraint2 = Constraint(rule=constraint_rule2)
#     '''
#     Salt constraint
#     '''
#     def constraint_rule3(model):
#         return model.x['Salt'] == 0.05
#     model.Constraint3 = Constraint(rule=constraint_rule3)
    
    return model

# %% [markdown]
# ## Step 2: Data Processing

# %%
y = dataset['label']
X = dataset.drop(['label'], axis=1, inplace=False)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.8, random_state=42)

# %% [markdown]
# Check ground truth function.

# %%
# y_true = [check_violation(0.5, X_train.iloc[i,:])[1] for i in range(X_train.shape[0])]
# y_compare = pd.DataFrame({'y_train':y_train,
#     'y_calc':y_true, 
#     'diff':abs(y_train - y_true),
#     'match':(np.round(y_true,2)==np.round(y_train, 2))})

# %% [markdown]
# ## Part 3: Learn the predictive models
# 'alg_list' specifies the list of algorithms that you will consider in the training pipeline. If you have the InterpretableAI license, you can include **iai** (Optimal Trees with Hyperplanes) or **iai-single** (Optimal Trees with single feature splits) in the list. If using IAI, you must specify the metric as 'r2'. Otherwise, the default metric is 'neg_squared_mse'.

# %% [markdown]
# #### Goldfarb and Iyengar: closed-form solution

# %%
A = X_train
A_cols = A.columns
A = np.matrix(A)

# %%
## OLS estimator
B_hat = ((A.T @ A).I @ A.T) @ np.matrix(y_train).T
resids = np.matrix(y_train).T - (A @ B_hat)
n_features = A.shape[1] # m+1 in iyengar goldfarb
n_samples = A.shape[0] # p in IG
σ_sq = np.square(resids).sum() / (n_samples - n_features) # square of L2 norm / (num samples - num features)

# %%
from scipy.stats import f

# %%
f_dist = f(dfn = A.shape[1], dfd = A.shape[0] - A.shape[1])
w_crit = f_dist.ppf(q = 0.95)

# %%
B_temp = B_hat + 0.001

# %%
## P() = w (.95)
(B_temp - B_hat).T @ (A.T @ A) @ (B_temp - B_hat) <= n_features*w_crit*σ_sq
# Out:
# matrix([[ True]])

# %%
N = X_train.columns
Q = pd.DataFrame((A.T  @ A).I, columns = N, index = N)

# %%
 np.all(np.linalg.eigvals((A.T  @ A).I) > 0)
# Out:
# True

# %%
model.x['Beans']

# %%
np.random.seed(0)
price_random = pd.Series(np.random.random(len(cost_p))*1000)
price_random.index = cost_p.index

conceptual_model = init_conceptual_model(price_random)
model_master = pd.DataFrame()
model = opticl.optimization_MIP(conceptual_model, conceptual_model.x, model_master, X_train, 
                                          tr=True)

## Inputs into function
outcome = 'palatability'
threshold = 0.5;
lb = threshold; ub = np.nan;
weight_objective = 0; 
task = 'continuous'
data = X_train
Γ = 0.5

## Inner function to embed constraint
N = X_train.columns


coeff = pd.DataFrame(B_hat.T, columns = N).loc[0,:]

model.add_component('LR'+outcome, 
                    Constraint(expr=model.y[outcome] == sum(model.x[i] * coeff.loc[i] for i in N)))

model.add_component('lb_' + outcome, Constraint(expr=model.y[outcome] - np.sqrt(Γ)*sum(model.x[i]*Q.loc[i,j]*model.x[j] for i in N for j in N) <= lb))

# model.write('test_robust_cf.lp')
# Out:
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.

# %%
opt = SolverFactory('gurobi')
# opt.options['NonConvex'] = 2
start_time = time.time()
results = opt.solve(model) 
computation_time = time.time() - start_time
pred_palat = value(model.y['palatability'])
# violation_bool, real_palat = check_violation(threshold,  model.x.get_values())
# Out:
# ERROR: Solver (gurobi) returned non-zero return code (1)
# ERROR: Solver log: Academic license - for non-commercial use only - expires
#     2022-08-14 Using license file /Users/hollywiberg/gurobi.lic Read LP format
#     model from file
#     /var/folders/n9/m94rpfdx0r1d_ltdt2pgzwy80000gn/T/tmpcnncmcf_.pyomo.lp
#     Reading time = 0.01 seconds x1025: 37 rows, 1025 columns, 8121 nonzeros
#     Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64) Thread count: 4
#     physical cores, 8 logical processors, using up to 8 threads Optimize a
#     model with 37 rows, 1025 columns and 8121 nonzeros Model fingerprint:
#     0x1ecb7a38 Model has 1 quadratic constraint Coefficient statistics:
#       Matrix range     [5e-05, 2e+03] QMatrix range    [5e-05, 2e+00] QLMatrix
#       range   [1e+00, 1e+00] Objective range  [2e+01, 1e+03] Bounds range
#       [1e+00, 1e+00] RHS range        [9e-01, 2e+03] QRHS range       [5e-01,
#       5e-01]
#     Presolve removed 1 rows and 1 columns Traceback (most recent call last):
#       File "<stdin>", line 5, in <module> File
#       "/Users/hollywiberg/opt/anaconda3/lib/python3.7/site-
#       packages/pyomo/solvers/plugins/solvers/GUROBI_RUN.py", line 114, in
#       gurobi_run
#         model.optimize()
#       File "src/gurobipy/model.pxi", line 847, in gurobipy.Model.optimize
#     gurobipy.GurobiError: Constraint Q not PSD (diagonal adjustment of 3.8e+01
#     would be required). Set NonConvex parameter to 2 to solve model.
# ---------------------------------------------------------------------------
# ApplicationError                          Traceback (most recent call last)
# /var/folders/n9/m94rpfdx0r1d_ltdt2pgzwy80000gn/T/ipykernel_2713/4117101470.py in <module>
#       2 # opt.options['NonConvex'] = 2
#       3 start_time = time.time()
# ----> 4 results = opt.solve(model)
#       5 computation_time = time.time() - start_time
#       6 pred_palat = value(model.y['palatability'])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pyomo/opt/base/solvers.py in solve(self, *args, **kwds)
#     594                     logger.error("Solver log:\n" + str(_status.log))
#     595                 raise ApplicationError(
# --> 596                     "Solver (%s) did not exit normally" % self.name)
#     597             solve_completion_time = time.time()
#     598             if self._report_timing:
#
# ApplicationError: Solver (gurobi) did not exit normally

# %%
from sklearn import metrics
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import ElasticNet, LinearRegression
from sklearn.tree import DecisionTreeRegressor, plot_tree

# %% [markdown]
# ### Bootstrapped intervals

# %%
from sklearn.utils import resample
from scipy.stats import bootstrap

from julia import Julia
Julia(compiled_modules=False)
from interpretableai import iai
# Out:
# WARNING:root:This copy of Interpretable AI software is for academic purposes only and not for commercial use.

# %%
gs.get_grid_results()
# Out:
#    minbucket        cp  train_score  valid_score  rank_valid_score
# 0          5  0.011382     0.677940     0.401704                 1
# 1         10  0.000927     0.673372     0.387928                 2

# %% [markdown]
# #### IAI with hyperplanes

# %%
# results = []
results_nosparse = []
n_resample = 5
for s in range(n_resample):
    print(s)
    X_sub, y_sub = resample(X_train, y_train, n_samples = int(.5*X_train.shape[0]), random_state = s)
    est = iai.OptimalTreeRegressor(
                random_seed=1,
                ls_num_hyper_restarts = 5, # 5 is default
                fast_num_support_restarts = 10,
                hyperplane_config={'sparsity':'all'},
                max_depth = 2,
            )
    gs = iai.GridSearch(est, minbucket = [5,10])              
    gs.fit(X_sub, y_sub)
    grid_result = gs.get_grid_results()
    valid_score = grid_result.query('rank_valid_score == 1')['valid_score'].values[0]
    best_params = gs.get_best_params()
    param_grid = {'minbucket': grid_result['minbucket'].unique(),
    'max_depth':2}
    model = gs.get_learner()
    results_nosparse.append(model)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for s in range(n_resample):
    results_nosparse[s].show_in_browser()

# %% [markdown]
# #### Linear regression (no regularization)

# %%
results = []
n_resample = 100
for s in range(n_resample):
    X_sub, y_sub = resample(X_train, y_train, n_samples = int(.5*X_train.shape[0]), random_state = s)
    est = LinearRegression()
    est.fit(X_sub, y_sub)
    results.append(est)
coefs = pd.DataFrame(np.stack([results[s].coef_ for s in range(n_resample)]))
coefs.columns = X_train.columns
coefs['intercept'] = [results[s].intercept_ for s in range(n_resample)]

# %%
coefs.median(axis=0)
# Out:
# Beans                          -1.723183e-01
# Bulgur                         -5.785947e-02
# Cheese                         -8.094977e-01
# Fish                           -5.216572e-01
# Meat                           -9.716336e-01
# CSB                            -1.568614e+00
# Dates                          -6.459638e-02
# DSM                            -4.171014e-01
# Milk                           -4.178734e-01
# Salt                           -4.336809e-16
# Lentils                        -1.400356e-01
# Maize                          -6.333926e-02
# Maize meal                     -6.472050e-02
# Chickpeas                      -9.967434e-02
# Rice                           -6.283761e-02
# Sorghum                        -6.427730e-02
# Soya-fortified bulgur wheat    -1.434997e+00
# Soya-fortified maize meal      -1.926228e+00
# Soya-fortified sorghum grits   -8.655736e-01
# Soya-fortified wheat flour     -1.194380e+00
# Sugar                          -8.326673e-17
# Oil                            -5.430939e-01
# Wheat                          -6.537613e-02
# Wheat flour                    -5.773921e-02
# WSB                            -1.493772e+00
# intercept                       2.324894e+00
# dtype: float64

# %%
coefs_ci = pd.DataFrame(columns=coefs.columns)
coefs_ci.loc['median',:] = coefs.median(axis=0)
coefs_ci.loc['lb_ci95',:] = np.percentile(coefs,2.5,axis=0)
coefs_ci.loc['ub_ci95',:] = np.percentile(coefs,97.5,axis=0)
coefs_ci.loc['midpoint',:] = (coefs_ci.loc['ub_ci95',:]+coefs_ci.loc['lb_ci95',:])/2
coefs_ci.loc['interval',:] = (coefs_ci.loc['ub_ci95',:]-coefs_ci.loc['midpoint',:])

# %%
np.random.seed(0)
price_random = pd.Series(np.random.random(len(cost_p))*1000)
price_random.index = cost_p.index

conceptual_model = init_conceptual_model(price_random)
model_master = pd.DataFrame()
model = opticl.optimization_MIP(conceptual_model, conceptual_model.x, model_master, X_train, 
                                          tr=True)

## Inputs into function
coefficients = coefs_ci
outcome = 'palatability'
threshold = 0.5;
lb = threshold; ub = np.nan;
weight_objective = 0; 
task = 'continuous'
data = X_train
Γ = 0.5

## Inner function to embed constraint
N = data.columns

intercept = coefficients['intercept'][0]
intercept_u = coefficients['intercept'][0]
coeff = coefficients.drop(['intercept'], axis=1, inplace=False).loc['midpoint', :]
coeff_u = coefficients.drop(['intercept'], axis=1, inplace=False).loc['interval', :]
# model.add_component('LR'+outcome, 
#                     Constraint(expr=model.y[outcome] == sum(model.x[i] * coeff.loc[i] for i in N) + intercept))
model.add_component('LR'+outcome, 
                    Constraint(expr=model.y[outcome] == sum(model.x[i] * coeff.loc[i] for i in N) + intercept
                              + Γ*(1/len(N)+1)*sum((model.x[i]*model.x[i] * coeff_u.loc[i]**2) for i in N)))

model.add_component('lb_' + outcome, Constraint(expr=model.y[outcome] >= lb))

model.write('test_robust.lp')
# Out:
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# ('test_robust.lp', 140275138601296)

# %%
    
opt = SolverFactory('gurobi')
opt.options['NonConvex'] = 2
start_time = time.time()
results = opt.solve(model) 
computation_time = time.time() - start_time
pred_palat = value(model.y['palatability'])
violation_bool, real_palat = check_violation(threshold,  model.x.get_values())

# %%
pred_palat
# Out:
# 0.5

# %%
real_palat
# Out:
# 0.7183851018295528

# %% [markdown]
# #### CART

# %%
results_shallow = []
constraints_shallow = []
alg = 'cart'
task_type = 'continuous'
outcome = 'temp'

for s in range(10):
    X_sub, y_sub = resample(X_train, y_train, n_samples = int(.5*X_train.shape[0]), random_state = s)
    m, perf = opticl.run_model(X_sub, y_sub, X_test, y_test, alg, outcome, task = task_type,
                       seed = s, cv_folds = 5, 
                       parameter_grid = {"max_depth": [1,2],
                                'min_samples_leaf': [0.02, 0.04, 0.06],
                                "max_features": [0.4, 0.6, 0.8, 1.0]},
                       save = False,
                      )
    constraintL = opticl.ConstraintLearning(X_sub, y_sub, m, alg)
    constraint_add = constraintL.constraint_extrapolation(task_type)
    constraint_add['sample'] = s
    results_shallow.append(m)
    constraints_shallow.append(constraint_add)
    
    plt.figure(figsize = (20,10))
    plot_tree(results_shallow[s],
                   filled=True,feature_names = train_x.columns, fontsize = 12)  
    plt.savefig('results/temp_tree%d.png' % s,format='png',bbox_inches = "tight")
# Out:
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = cart, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.02577521263180475
# Train R2: 0.5068797672428444
# -------------------testing evaluation-----------------------
# Test MSE: 0.026921386672781992
# Test R2: 0.4741360985468972
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/n9/m94rpfdx0r1d_ltdt2pgzwy80000gn/T/ipykernel_61604/3192821630.py in <module>
#      20     constraints_shallow.append(constraint_add)
#      21
# ---> 22     plt.figure(figsize = (20,10))
#      23     plot_tree(results_shallow[s],
#      24                    filled=True,feature_names = train_x.columns, fontsize = 12)
#
# NameError: name 'plt' is not defined

# %% [markdown]
# #### MLP

# %%
results_mlp = []
constraints_mlp = []
alg = 'mlp'
task_type = 'continuous'
outcome = 'temp'

for s in range(25):
    X_sub, y_sub = X_train, y_train
#     X_sub, y_sub = resample(X_train, y_train, n_samples = int(.5*X_train.shape[0]), random_state = s)
    m, perf = opticl.run_model(X_sub, y_sub, X_test, y_test, alg, outcome, task = task_type,
                       seed = s, cv_folds = 5, 
                       parameter_grid = {'hidden_layer_sizes': [(5,)]},
                       save = False,
                      )
    constraintL = opticl.ConstraintLearning(X_sub, y_sub, m, alg)
    constraint_add = constraintL.constraint_extrapolation(task_type)
    constraint_add['sample'] = s
    results_mlp.append(m)
    constraints_mlp.append(constraint_add)
# Out:
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.04404702130396748
# Train R2: 0.1007471564623974
# -------------------testing evaluation-----------------------
# Test MSE: 0.0491405592406819
# Test R2: 0.04988159748587273
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.04896734120432957
# Train R2: 0.00029515016255898807
# -------------------testing evaluation-----------------------
# Test MSE: 0.05536235057940182
# Test R2: -0.07041492617735234
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.05477066734868286
# Train R2: -0.11818408822389115
# -------------------testing evaluation-----------------------
# Test MSE: 0.0590623032308219
# Test R2: -0.14195243321562945
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.034069994428907666
# Train R2: 0.30443561306730516
# -------------------testing evaluation-----------------------
# Test MSE: 0.03960986313378219
# Test R2: 0.23415483124342784
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.0391005601448641
# Train R2: 0.2017328560872519
# -------------------testing evaluation-----------------------
# Test MSE: 0.044494566750209276
# Test R2: 0.13971050931246165
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.044253819214655696
# Train R2: 0.09652522263534757
# -------------------testing evaluation-----------------------
# Test MSE: 0.04897033140007751
# Test R2: 0.05317290321127788
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.05595815360741323
# Train R2: -0.1424275072613761
# -------------------testing evaluation-----------------------
# Test MSE: 0.06008112494735259
# Test R2: -0.1616510544099008
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.061696121505426416
# Train R2: -0.2595724082254527
# -------------------testing evaluation-----------------------
# Test MSE: 0.06551813089531003
# Test R2: -0.26677398108299655
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.033138547195634145
# Train R2: 0.32345180413607544
# -------------------testing evaluation-----------------------
# Test MSE: 0.039239610770623407
# Test R2: 0.24131355286253942
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.04491072947143255
# Train R2: 0.08311390902394578
# -------------------testing evaluation-----------------------
# Test MSE: 0.048348870997162126
# Test R2: 0.06518865912385874
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.03553619530614662
# Train R2: 0.2745020268900328
# -------------------testing evaluation-----------------------
# Test MSE: 0.04085555573904586
# Test R2: 0.21006972748341712
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.03550965164448708
# Train R2: 0.2750439355712242
# -------------------testing evaluation-----------------------
# Test MSE: 0.04146095605149801
# Test R2: 0.19836448874302448
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.04351686263754875
# Train R2: 0.11157074167178371
# -------------------testing evaluation-----------------------
# Test MSE: 0.04781454467394248
# Test R2: 0.07551970298016086
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.04179064194923508
# Train R2: 0.14681282652985073
# -------------------testing evaluation-----------------------
# Test MSE: 0.04648546256507663
# Test R2: 0.10121711850815318
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.050910656167569075
# Train R2: -0.03937907648996797
# -------------------testing evaluation-----------------------
# Test MSE: 0.05593292715910163
# Test R2: -0.08144685818612696
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.057337607551939174
# Train R2: -0.17059009000638414
# -------------------testing evaluation-----------------------
# Test MSE: 0.061802749876355964
# Test R2: -0.194938171051402
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.035695277517519164
# Train R2: 0.27125424470867276
# -------------------testing evaluation-----------------------
# Test MSE: 0.04089285142872353
# Test R2: 0.20934862618451544
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.030210957676122852
# Train R2: 0.38322073111898314
# -------------------testing evaluation-----------------------
# Test MSE: 0.03405582131089812
# Test R2: 0.34154061247577916
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.0562129846696101
# Train R2: -0.14763007375777604
# -------------------testing evaluation-----------------------
# Test MSE: 0.06048766704042853
# Test R2: -0.16951142738889402
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.04268423592186214
# Train R2: 0.12856943805398657
# -------------------testing evaluation-----------------------
# Test MSE: 0.04692132504271079
# Test R2: 0.09278984443222493
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.0342309566840877
# Train R2: 0.30114944838720137
# -------------------testing evaluation-----------------------
# Test MSE: 0.037011821930651376
# Test R2: 0.28438720132075057
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.05337470716195485
# Train R2: -0.08968451821398049
# -------------------testing evaluation-----------------------
# Test MSE: 0.05721213136852299
# Test R2: -0.10617989905348812
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.055900208185630476
# Train R2: -0.1412445081898035
# -------------------testing evaluation-----------------------
# Test MSE: 0.05943627795070978
# Test R2: -0.14918312551809687
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.04775572917078968
# Train R2: 0.02503111491500376
# -------------------testing evaluation-----------------------
# Test MSE: 0.05229493034246696
# Test R2: -0.011107249171037337
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.035906041328797184
# Train R2: 0.26695134405850984
# -------------------testing evaluation-----------------------
# Test MSE: 0.04209174860644203
# Test R2: 0.1861682983886207

# %%
df_mlp = pd.concat(constraints_mlp)
df_mlp['id'] = df_mlp.apply(lambda row: '%d_%d' % (row['sample'],row['node']), axis = 1)

# %%
df_clust = df_mlp.query('layer == 0').drop(columns=['layer','node','sample'])
df_clust.set_index('id', inplace = True)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.preprocessing import StandardScaler


df_clust_std = StandardScaler().fit_transform(df_clust)

distortions = []
sm = []
K = range(2,20)
for k in K:
    km = KMeans(n_clusters=k)
    km.fit(df_clust_std)
    distortions.append(km.inertia_)
    sm.append(silhouette_score(df_clust_std, km.labels_))

# %%
km_final = KMeans(n_clusters=5).fit(df_clust_std)

# %%
df_clust['cluster'] = km_final.labels_

# %%
km_final.labels_
# Out:
# array([2, 4, 0, 2, 4, 2, 3, 2, 2, 1, 1, 0, 3, 2, 2, 2, 0, 2, 2, 4, 0, 0,
#        0, 2, 0, 0, 0, 3, 1, 3, 1, 3, 3, 1, 0, 3, 1, 2, 1, 1, 0, 4, 0, 2,
#        1, 3, 1, 3, 3, 3, 3, 1, 3, 0, 4, 0, 3, 2, 0, 4, 3, 4, 2, 2, 2, 1,
#        2, 0, 3, 2, 3, 3, 1, 2, 3, 2, 0, 2, 1, 1, 2, 1, 4, 2, 2, 4, 0, 1,
#        1, 1, 2, 1, 1, 1, 0, 2, 1, 0, 1, 1, 1, 4, 1, 0, 3, 3, 3, 3, 0, 1,
#        1, 2, 0, 2, 1, 1, 3, 0, 2, 3, 1, 1, 4, 2, 3], dtype=int32)

# %%
df_clust
# Out:
#       intercept    node_0    node_1    node_2    node_3    node_4    node_5  \
# id
# 0_0   -0.192090 -0.051330  0.038285  0.159164 -0.486206  0.370750 -0.009431
# 0_1    0.196546  0.070352  0.287314  0.739568  0.283704  0.716930  0.355266
# 0_2    0.021915  0.059912  0.199503 -0.236768  0.033368 -0.376823  0.152468
# 0_3    0.319920  0.018348  0.285793  0.137375 -0.051267  0.087529 -0.240628
# 0_4    0.101291 -0.150717  0.212394  0.263515  0.886851  0.304279  0.471611
# ...         ...       ...       ...       ...       ...       ...       ...
# 24_0  -0.028950  0.365894  0.376940 -0.439462 -0.488145  0.077992  0.238954
# 24_1  -0.185351  0.043143  0.301657  0.034122  0.407265  0.038671  0.343987
# 24_2  -0.405942  0.314824  0.082223  0.593928  0.445128  0.391151  0.294220
# 24_3   0.124603 -0.437484 -0.359468  0.169949 -0.150703 -0.012590 -0.072050
# 24_4  -0.130863  0.070752  0.247875 -0.214930  0.064351  0.232422 -0.225986
#
#         node_6    node_7    node_8  ...   node_14   node_15   node_16  \
# id                                  ...
# 0_0  -0.284960  0.033945 -0.237019  ...  0.286745 -0.599725 -0.300206
# 0_1   0.261215 -0.307240  0.136811  ...  0.285664  0.453056  0.871517
# 0_2  -0.119253  0.129447  0.063120  ...  0.287425 -0.600685 -0.653781
# 0_3   0.004205  0.455685 -0.523829  ... -0.038386 -0.476996 -0.190153
# 0_4  -0.408317 -0.193947  0.226614  ...  0.423816  0.100878  0.556217
# ...        ...       ...       ...  ...       ...       ...       ...
# 24_0  0.077148  0.261453 -0.256609  ...  0.026988  0.160036 -0.460461
# 24_1  0.176164  0.119126  0.088885  ...  0.181652  0.356734  0.000460
# 24_2  0.323016 -0.203816 -0.072727  ...  0.406456 -0.037521  0.294922
# 24_3 -0.050455  0.176763 -0.512696  ... -0.133883  0.075921 -0.109695
# 24_4  0.144591 -0.032667 -0.218693  ...  0.358364  0.223606 -0.541808
#
#        node_17   node_18   node_19   node_20   node_21   node_22  cluster
# id
# 0_0  -0.359261 -0.304104 -0.379760  0.037109 -0.001645 -0.140200        2
# 0_1   0.291878  0.853912 -0.026116  0.152293 -0.263396 -0.012205        4
# 0_2  -0.598056 -0.652159 -0.504777  0.065649  0.203845  0.173537        0
# 0_3  -0.096805 -0.091453  0.264889  0.307436 -0.237137 -0.169341        2
# 0_4   0.718752  0.448410 -0.507323  0.041455  0.275261  0.148278        4
# ...        ...       ...       ...       ...       ...       ...      ...
# 24_0 -0.047585 -0.251922 -0.255886  0.088210 -0.099144  0.331491        1
# 24_1 -0.416271  0.148548 -0.053905  0.127380 -0.070899 -0.247296        1
# 24_2  0.657125  0.574307  0.066674  0.066188 -0.411847  0.236671        4
# 24_3 -0.531092 -0.636965 -0.434010  0.253119 -0.339540 -0.301764        2
# 24_4 -0.307338  0.016308 -0.269327  0.061609 -0.762425 -0.354931        3
#
# [125 rows x 25 columns]

# %%
df_clust.to_csv('results/mlp_constraints_bootstrapped_fulldata.csv', index = True)

# %% [markdown]
# ## Step 4: Predictive model selection and Optimization

# %%
threshold = 0.5
trust_region = True

# %%
version = 'TPDP_v1'
outcome_list = ['palatability']
constraints_embed = ['palatability']
objectives_embed = {}
performance = pd.read_csv('results/%s_performance.csv' % version)
performance.dropna(axis='columns')
performance['task'] = task

# %%
performance
# Out:
#                                        save_path  seed  cv_folds  \
# 0     results/mlp/TPDP_v1_palatability_model.csv     1         5
# 1  results/linear/TPDP_v1_palatability_model.csv     1         5
# 2    results/cart/TPDP_v1_palatability_model.csv     1         5
# 3      results/rf/TPDP_v1_palatability_model.csv     1         5
# 4     results/svm/TPDP_v1_palatability_model.csv     1         5
# 5     results/gbm/TPDP_v1_palatability_model.csv     1         5
#
#                                           parameters  \
# 0  {'hidden_layer_sizes': [(10,), (20,), (50,), (...
# 1  {'alpha': [0.1, 1, 10, 100, 1000], 'l1_ratio':...
# 2  {'max_depth': [3, 4, 5, 6, 7, 8, 9, 10], 'min_...
# 3  {'n_estimators': [10, 25], 'max_features': ['a...
# 4                           {'C': [0.1, 1, 10, 100]}
# 5  {'learning_rate': [0.01, 0.025, 0.05, 0.075, 0...
#
#                                          best_params  valid_score  \
# 0                     {'hidden_layer_sizes': (100,)}    -0.019855
# 1                    {'alpha': 0.1, 'l1_ratio': 0.1}    -0.045594
# 2  {'max_depth': 10, 'max_features': 1.0, 'min_sa...    -0.016014
# 3  {'max_depth': 4, 'max_features': 'auto', 'n_es...    -0.016288
# 4                                         {'C': 100}    -0.019034
# 5  {'learning_rate': 0.2, 'max_depth': 5, 'n_esti...    -0.008328
#
#    train_score  train_r2  test_score   test_r2  auc_train  auc_test  \
# 0     0.011065  0.783251    0.018395  0.641899        NaN       NaN
# 1     0.044942  0.119613    0.046470  0.095323        NaN       NaN
# 2     0.010676  0.790856    0.015873  0.690982        NaN       NaN
# 3     0.013386  0.737770    0.016551  0.677784        NaN       NaN
# 4     0.018145  0.644559    0.019587  0.618690        NaN       NaN
# 5     0.003146  0.938371    0.008673  0.831147        NaN       NaN
#
#         outcome     alg        task
# 0  palatability     mlp  continuous
# 1  palatability  linear  continuous
# 2  palatability    cart  continuous
# 3  palatability      rf  continuous
# 4  palatability     svm  continuous
# 5  palatability     gbm  continuous

# %%
model_master = opticl.model_selection(performance.query('alg == "%s"' % 'rf'), 
                                      constraints_embed, objectives_embed)
# Out:
#         outcome model_type                                  save_path  \
# 0  palatability         rf  results/rf/TPDP_v1_palatability_model.csv
#
#          task  objective
# 0  continuous          0

# %%
model_master
# Out:
#         outcome model_type                                  save_path  \
# 0  palatability         rf  results/rf/TPDP_v1_palatability_model.csv
#
#          task  objective
# 0  continuous          0

# %%
columns_df = ['algorithm','iteration','price_matrix']+list(X.columns)+['objective_function', 'real_palat', 'pred_palat', 'violation', 'time']
solutions_df = pd.DataFrame(columns = columns_df)
iterations = 25  # 1000

for alg in alg_list:
    print(f"\nAlgorithm: {alg}")
    
    model_master = opticl.model_selection(performance.query('alg == "%s"' % alg), 
                                      constraints_embed, objectives_embed)
    model_master['lb'] = threshold
    model_master['ub'] = None
    opticl.check_model_master(model_master)

    for i in range(iterations):
        print(f"Iteration {i}")
        np.random.seed(i)
        price_random = pd.Series(np.random.random(len(cost_p))*1000)
        price_random.index = cost_p.index

        conceptual_model= init_conceptual_model(price_random)
        MIP_final_model = opticl.optimization_MIP(conceptual_model, conceptual_model.x, model_master, X, 
                                                  tr=True)
        opt = SolverFactory('gurobi')
        start_time = time.time()
        results = opt.solve(MIP_final_model) 
        computation_time = time.time() - start_time
        pred_palat = value(MIP_final_model.y['palatability'])
        violation_bool, real_palat = check_violation(threshold,  MIP_final_model.x.get_values())
        ## Save solutions
        solution = MIP_final_model.x.get_values()
        solution['algorithm'] = alg
        solution['iteration'] =i
        solution['price_matrix'] = price_random.to_dict()
        solution['violation'] = violation_bool
        solution['real_palat'] = real_palat
        solution['pred_palat'] = pred_palat
        solution['objective_function'] = value(MIP_final_model.OBJ)
        solution['time'] = computation_time
        solutions_df = solutions_df.append(solution, ignore_index=True)
        print(f"The predicted palatability of the optimal solution is {pred_palat}")
# Out:
# Algorithm: linear
#         outcome model_type                                      save_path  \
# 0  palatability     linear  results/linear/TPDP_v1_palatability_model.csv
#
#          task  objective
# 0  continuous          0
# No learned objective
#
# Embedding constraint for palatability using linear model.
# 0.5 <= palatability
# Iteration 0
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 1
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 2
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5263742138343516
# Iteration 3
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5703105631059203
# Iteration 4
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 5
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.566101568204608
# Iteration 6
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 7
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 8
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5061827607760164
# Iteration 9
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5048992802040595
# Iteration 10
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 11
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.515467333180446
# Iteration 12
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 13
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5203574332547383
# Iteration 14
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5670042985685477
# Iteration 15
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5263741982211254
# Iteration 16
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 17
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 18
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5014554633374169
# Iteration 19
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 20
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5683942243912793
# Iteration 21
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 22
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5225229885758039
# Iteration 23
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5156372992273306
# Iteration 24
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5220706823630124
#
# Algorithm: cart
#         outcome model_type                                    save_path  \
# 0  palatability       cart  results/cart/TPDP_v1_palatability_model.csv
#
#          task  objective
# 0  continuous          0
# No learned objective
#
# Embedding constraint for palatability using cart model.
# 0.5 <= palatability
# Iteration 0
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5527527524722223
# Iteration 1
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5123039259677419
# Iteration 2
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5497993538076923
# Iteration 3
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.8062892521200002
# Iteration 4
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.7453189247368421
# Iteration 5
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5497993538076923
# Iteration 6
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5680031480740743
# Iteration 7
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5123039259677419
# Iteration 8
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6840129299500001
# Iteration 9
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5123039259677419
# Iteration 10
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5123039259677419
# Iteration 11
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5527527524722223
# Iteration 12
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.7453189247368421
# Iteration 13
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5527527524722223
# Iteration 14
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6602250677727274
# Iteration 15
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5497993538076923
# Iteration 16
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6840129299500001
# Iteration 17
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6957545561
# Iteration 18
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.549799357151573
# Iteration 19
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5123039259677419
# Iteration 20
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5938216374
# Iteration 21
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5123039259677419
# Iteration 22
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5938216374
# Iteration 23
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5123039259677419
# Iteration 24
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5938216374
#
# Algorithm: rf
#         outcome model_type                                  save_path  \
# 0  palatability         rf  results/rf/TPDP_v1_palatability_model.csv
#
#          task  objective
# 0  continuous          0
# No learned objective
#
# Embedding constraint for palatability using rf model.
# 0.5 <= palatability
# Iteration 0
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5577597223187226
# Iteration 1
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5037773689971803
# Iteration 2
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5823601329902334
# Iteration 3
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5823601329902334
# Iteration 4
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6328885172139289
# Iteration 5
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5009306092106649
# Iteration 6
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.732144807426753
# Iteration 7
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5037515489741564
# Iteration 8
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5030473773771512
# Iteration 9
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5027778671983015
# Iteration 10
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5009807573225945
# Iteration 11
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6048265548166682
# Iteration 12
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6328885172139289
# Iteration 13
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5795898713089391
# Iteration 14
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6328885172139289
# Iteration 15
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5823601329902334
# Iteration 16
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5144251446018163
# Iteration 17
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6816164232030573
# Iteration 18
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5060464385432839
# Iteration 19
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5037773689971803
# Iteration 20
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5136962953334835
# Iteration 21
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.502615526380193
# Iteration 22
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5049866520008632
# Iteration 23
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5278823759952237
# Iteration 24
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6619847689686196
#
# Algorithm: svm
#         outcome model_type                                   save_path  \
# 0  palatability        svm  results/svm/TPDP_v1_palatability_model.csv
#
#          task  objective
# 0  continuous          0
# No learned objective
#
# Embedding constraint for palatability using svm model.
# 0.5 <= palatability
# Iteration 0
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 1
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 2
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 3
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6177837738831746
# Iteration 4
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5112822911761427
# Iteration 5
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 6
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5552964173169787
# Iteration 7
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5588529798055266
# Iteration 8
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 9
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 10
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 11
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5562914215251452
# Iteration 12
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5207445764895235
# Iteration 13
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 14
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.717536995047638
# Iteration 15
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 16
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5191850623201552
# Iteration 17
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5171512147660484
# Iteration 18
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5687894449345211
# Iteration 19
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 20
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 21
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 22
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5
# Iteration 23
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5374105564842286
# Iteration 24
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5490014521819118
#
# Algorithm: gbm
#         outcome model_type                                   save_path  \
# 0  palatability        gbm  results/gbm/TPDP_v1_palatability_model.csv
#
#          task  objective
# 0  continuous          0
# No learned objective
#
# Embedding constraint for palatability using gbm model.
# 0.5 <= palatability
# Iteration 0
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5514769531815001
# Iteration 1
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5006498000570162
# Iteration 2
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5174993516040896
# Iteration 3
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5669949876998378
# Iteration 4
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6663878162160444
# Iteration 5
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5057802047783372
# Iteration 6
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6122489166731873
# Iteration 7
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5812449995019768
# Iteration 8
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5205109228966862
# Iteration 9
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5036995957817828
# Iteration 10
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5007872332617097
# Iteration 11
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6230645976112993
# Iteration 12
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.594452470583912
# Iteration 13
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.516831970069418
# Iteration 14
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5953135341122426
# Iteration 15
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5174993516040918
# Iteration 16
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5121686220553617
# Iteration 17
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6936004494279743
# Iteration 18
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5088308707661399
# Iteration 19
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.526871110956053
# Iteration 20
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5032386439779268
# Iteration 21
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5052276156287955
# Iteration 22
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5028791347693086
# Iteration 23
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5014025712351913
# Iteration 24
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5850147787413945

# %%
solutions_df_robust = solutions_df.copy()

# %%
solutions_df_robust['max_violation'] = np.nan

# %%
columns_df = ['algorithm','iteration','price_matrix']+list(X.columns)+['objective_function', 'real_palat', 'pred_palat', 'violation', 'time']
solutions_df = pd.DataFrame(columns = columns_df)
iterations = 25  # 1000
alg = 'linear'
for Γ in [0.5, 1, 2]:
    for i in range(iterations):
            print(f"Iteration {i}")
            np.random.seed(i)
            price_random = pd.Series(np.random.random(len(cost_p))*1000)
            price_random.index = cost_p.index
            conceptual_model = init_conceptual_model(price_random)


            model_master = pd.DataFrame()
            model = opticl.optimization_MIP(conceptual_model, conceptual_model.x, model_master, X_train, 
                                              tr=True)


            ## Inputs into function
            coefficients = coefs_ci
            outcome = 'palatability'
            threshold = 0.5;
            task = 'continuous'
            data = X_train

            ## Inner function to embed constraint
            N = data.columns

            intercept = coefficients['intercept'][0]
            intercept_u = coefficients['intercept'][0]
            coeff = coefficients.drop(['intercept'], axis=1, inplace=False).loc['midpoint', :]
            coeff_u = coefficients.drop(['intercept'], axis=1, inplace=False).loc['interval', :]
            # model.add_component('LR'+outcome, 
            #                     Constraint(expr=model.y[outcome] == sum(model.x[i] * coeff.loc[i] for i in N) + intercept))
            model.add_component('LR'+outcome, 
                                Constraint(expr=model.y[outcome] == sum(model.x[i] * coeff.loc[i] for i in N) + intercept
                                          + Γ*(1/len(N)+1)*sum((model.x[i]*model.x[i] * coeff_u.loc[i]**2) for i in N)))

            model.add_component('lb_' + outcome, Constraint(expr=model.y[outcome] >= lb))

            opt = SolverFactory('gurobi')
            opt.options['NonConvex'] = 2
            start_time = time.time()
            results = opt.solve(model) 
            computation_time = time.time() - start_time
            pred_palat = value(model.y['palatability'])
            violation_bool, real_palat = check_violation(threshold,  model.x.get_values())
            ## Save solutions
            solution = model.x.get_values()
            solution['algorithm'] = alg
            solution['iteration'] =i
            solution['price_matrix'] = price_random.to_dict()
            solution['violation'] = violation_bool
            solution['real_palat'] = real_palat
            solution['pred_palat'] = pred_palat
            solution['objective_function'] = value(model.OBJ)
            solution['time'] = computation_time
            solution['max_violation'] = Γ
            solutions_df = solutions_df.append(solution, ignore_index=True)
            print(f"The predicted palatability of the optimal solution is {pred_palat}")
# Out:
# Iteration 0
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 1
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 2
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.505200079211692
# Iteration 3
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5818609739262413
# Iteration 4
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 5
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 6
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 7
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 8
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 9
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 10
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.6529165524073427
# Iteration 11
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5052000792123817
# Iteration 12
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5002278754780086
# Iteration 13
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5392850482515564
# Iteration 14
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5791093736020209
# Iteration 15
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.6518660951518951
# Iteration 16
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 17
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 18
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 19
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 20
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 21
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 22
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5080846721441193
# Iteration 23
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5128905128697995
# Iteration 24
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 0
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 1
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 2
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5231865699545505
# Iteration 3
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5962027823603118
# Iteration 4
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 5
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 6
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 7
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 8
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 9
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 10
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.6685343662420697
# Iteration 11
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5231865699548279
# Iteration 12
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5180117736735124
# Iteration 13
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5563095892610255
# Iteration 14
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5934608269409237
# Iteration 15
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.667328429194454
# Iteration 16
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5053129139403956
# Iteration 17
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5033348878325478
# Iteration 18
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 19
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 20
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 21
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 22
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5204929079106588
# Iteration 23
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5232972352567258
# Iteration 24
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 0
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 1
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 2
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5591595514396335
# Iteration 3
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.6248864880504199
# Iteration 4
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 5
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 6
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5223864637903667
# Iteration 7
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 8
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 9
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 10
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.6997699933397011
# Iteration 11
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.559159551439984
# Iteration 12
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5535795700645454
# Iteration 13
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5903583824775542
# Iteration 14
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.62216373361873
# Iteration 15
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.6982530972795704
# Iteration 16
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5379508000538183
# Iteration 17
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.533839616814904
# Iteration 18
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 19
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 20
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 21
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5
# Iteration 22
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5453092730000977
# Iteration 23
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5441106800305784
# Iteration 24
# Generating constraints for the trust region using 1000 samples.
# ... Trust region defined.
# The predicted palatability of the optimal solution is 0.5

# %%
solutions_df.to_clipboard()

# %%
iterations = 25  # 1000
alg = 'rf'
for viol_limit in [0.1,0.25]:
    print(f"\nAlgorithm: {alg}")
    
    model_master = opticl.model_selection(performance.query('alg == "%s"' % alg), 
                                      constraints_embed, objectives_embed)
    model_master['lb'] = threshold
    model_master['ub'] = None
    opticl.check_model_master(model_master)

    for i in range(iterations):
        print(f"Iteration {i}")
        np.random.seed(i)
        price_random = pd.Series(np.random.random(len(cost_p))*1000)
        price_random.index = cost_p.index

        conceptual_model= init_conceptual_model(price_random)
        MIP_final_model = opticl.optimization_MIP(conceptual_model, conceptual_model.x, model_master, X, 
                                                  tr=True, max_violation = viol_limit)
        opt = SolverFactory('gurobi')
        start_time = time.time()
        results = opt.solve(MIP_final_model) 
        computation_time = time.time() - start_time
        pred_palat = value(MIP_final_model.y['palatability'])
        violation_bool, real_palat = check_violation(threshold,  MIP_final_model.x.get_values())
        ## Save solutions
        solution = MIP_final_model.x.get_values()
        solution['algorithm'] = alg
        solution['iteration'] =i
        solution['price_matrix'] = price_random.to_dict()
        solution['violation'] = violation_bool
        solution['real_palat'] = real_palat
        solution['pred_palat'] = pred_palat
        solution['objective_function'] = value(MIP_final_model.OBJ)
        solution['time'] = computation_time
        solution['max_violation'] = viol_limit
        solutions_df_robust = solutions_df_robust.append(solution, ignore_index=True)
        print(f"The predicted palatability of the optimal solution is {pred_palat}")
# Out:
# Algorithm: rf
#         outcome model_type                                  save_path  \
# 0  palatability         rf  results/rf/TPDP_v1_palatability_model.csv
#
#          task  objective
# 0  continuous          0
# No learned objective
#
# Embedding constraint for palatability using rf model.
# 0.5 <= palatability
# Iteration 0
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.615007043462521
# Iteration 1
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6938226524328955
# Iteration 2
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5823601329902334
# Iteration 3
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5823601329902334
# Iteration 4
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6328885172139289
# Iteration 5
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5643008319482635
# Iteration 6
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.732144807426753
# Iteration 7
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6993937151345252
# Iteration 8
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.7240688135085839
# Iteration 9
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6525916699366696
# Iteration 10
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6495065336772757
# Iteration 11
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.615007043462521
# Iteration 12
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6328885172139289
# Iteration 13
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5951922421187041
# Iteration 14
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6328885172139289
# Iteration 15
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5823601329902334
# Iteration 16
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6496731425144269
# Iteration 17
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6816164232030573
# Iteration 18
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5643008319482635
# Iteration 19
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.710949375450794
# Iteration 20
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6561507126218391
# Iteration 21
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6993937151345252
# Iteration 22
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6265590274863032
# Iteration 23
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6993937151345252
# Iteration 24
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6619847689686196
#
# Algorithm: rf
#         outcome model_type                                  save_path  \
# 0  palatability         rf  results/rf/TPDP_v1_palatability_model.csv
#
#          task  objective
# 0  continuous          0
# No learned objective
#
# Embedding constraint for palatability using rf model.
# 0.5 <= palatability
# Iteration 0
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5577597223187226
# Iteration 1
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6406600107887065
# Iteration 2
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5823601329902334
# Iteration 3
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5823601329902334
# Iteration 4
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6328885172139289
# Iteration 5
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5242855331238258
# Iteration 6
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.732144807426753
# Iteration 7
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6477948512318573
# Iteration 8
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6482492033108889
# Iteration 9
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6090761502227865
# Iteration 10
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6241878122870709
# Iteration 11
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6048265548166682
# Iteration 12
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6328885172139289
# Iteration 13
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5795898713089391
# Iteration 14
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6328885172139289
# Iteration 15
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5823601329902334
# Iteration 16
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.599334698515187
# Iteration 17
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6816164232030573
# Iteration 18
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.546141297499739
# Iteration 19
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6482492033108919
# Iteration 20
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6034601067632442
# Iteration 21
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6477948512318575
# Iteration 22
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.5628196133735703
# Iteration 23
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6477948512318576
# Iteration 24
# Generating constraints for the trust region using 5000 samples.
# ... Trust region defined.
# Embedding constraints for palatability
# The predicted palatability of the optimal solution is 0.6619847689686196

# %%
solutions_df_robust['alg_name'] = solutions_df_robust['algorithm'] + solutions_df_robust['max_violation'].fillna('').astype('str')

# %%
solutions_df_robust.groupby('alg_name').agg(mean_pred_palat = ('pred_palat','mean'),
                                           mean_real_palat = ('real_palat','mean'),
                                           mean_violation = ('real_palat',lambda x: (x <= 0.5).mean()),
                                            mean_objective = ('objective_function','mean'))
# Out:
#           mean_pred_palat  mean_real_palat  mean_violation  mean_objective
# alg_name
# cart             0.592559         0.519344            0.36     1315.076693
# gbm              0.548547         0.519416            0.40     1314.236593
# linear           0.517326         0.475888            0.40     1377.951314
# rf               0.562095         0.529697            0.36     1322.287131
# rf0.1            0.645472         0.546753            0.36     1328.254158
# rf0.25           0.616541         0.540756            0.32     1325.859228
# rf0.5            0.575758         0.533302            0.36     1323.923979
# svm              0.529173         0.522048            0.44     1325.191670

# %%
solutions_df.to_csv('results/violations_by_method.csv')
