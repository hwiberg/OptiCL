# %%
import pandas as pd
import numpy as np
import time
import sys
import os
import opticl
import utils_gastric as gi

# Optimization modelling
from pyomo import environ
from pyomo.environ import *

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## Data loading

# %% [markdown]
# Load ```tox_summary```, which reports quantiles for various toxicities as candidate upper bounds

# %%
tox_summary = pd.read_csv('processed-data/gastric_toxicity_summary.csv')
tox_summary.set_index('outcome', inplace = True)

# %% [markdown]
# Load training and testing datasets for each outcome. Note that in this case, the training data (X) is the same for all outcomes, but our framework is generic to independent training sets. Thus, we load each as a separate file for this example.

# %%
outcomes = gi.outcomes
datasets_train = {}
datasets_test = {}

# Training datasets
for o in outcomes:
    data = pd.read_csv(f'processed-data/data_train_{o}.csv')
    y = data[o]
    X = data.drop([o], inplace=False, axis=1)
    datasets_train[o] = (X, y)
    
# Testing datasets
for o in outcomes:
    data = pd.read_csv(f'processed-data/data_test_{o}.csv')
    y = data[o]
    X = data.drop([o], inplace=False, axis=1)
    datasets_test[o] = (X, y)

# %% [markdown]
# ## Specify the outcomes and relevant parameters for ML training + optimization
# ```outcome_list``` is a dictionary where each key is an outcome, and each value is a dictionary corresponding to that outcome. The outcome-specific dictionary specifies relevant parameters and data for (1) ML model training and (2) the final optimization problem.

# %%
# Outcome list
outcomes = gi.outcomes

## ML training parameters: 
# specify models to consider, and optionally specify a grid to search over in CV (if None, will use default grid)
alg_dict = {'cart': None, 'linear':None, 'rf': None, 'mlp': None, 'gbm': None, 'svm': None}
# specify whether we train a single model (bs = 0) or bootstrapped models (bs >= 1) for the outcome
bs = 0
# if training multiple models, select the single best (gr = False) or group together as an ensemble (gr = True)
gr=False
# if grouping an ensemble, specify proportion that can violate (or "average" to constrain mean)
viol_rule = 0.5

# %% [markdown]
# Add all constraint outcomes to dictionary. For each toxicity, we want to enforce that the toxicity is below a certain quantile of the toxicities observed in the data (which we loaded in tox_summary). Here, we select the 70th percentile, givenin column ```quantile_0.7```.
#
# We also specify the training and testing data for ML model training as well as reporting test set metrics. dataset_path specifies the data that will be used to define the trust region in the downstream optimization task.

# %%
constraints_embed = gi.outcomes[:-1]
ub_quantile = 'quantile_0.7'

outcome_list = {outcome: {'lb':None, 'ub':tox_summary.loc[outcome,ub_quantile],
                          'objective_weight':0,'group_models':gr,
                        'task_type': 'continuous', 'alg_list':alg_dict, 'bootstrap_iterations':bs,
                        'X_train':datasets_train[outcome][0], 'y_train':datasets_train[outcome][1], 
                          'X_test':datasets_test[outcome][0], 'y_test':datasets_test[outcome][1],
                        'dataset_path': f'processed-data/data_train_{outcome}.csv'} 
                for outcome in constraints_embed}

# %% [markdown]
# Add the objective outcome to dictionary. In this case, the only outcome that we are seeking to optimize is overall survival (OS). We want to maximize survival; since the optimization formulation assumes that the objective will be minimized, we set the weight to -1.
#
# We similarly specify the training and testing sets and the trust region dataset path.

# %%
outcome_list['OS'] = {'lb':None, 'ub':None, 
                      'objective_weight':-1,'group_models':gr,
                        'task_type': 'continuous', 'alg_list':alg_dict, 'bootstrap_iterations':bs,
                       'X_train':datasets_train['OS'][0], 'y_train':datasets_train['OS'][1], 
                      'X_test':datasets_test['OS'][0], 'y_test':datasets_test['OS'][1],
                       'dataset_path':'processed-data/data_train_OS.csv'}

# %%
print("Algorithms = %s" % alg_dict)
print("Bootstrap iterations = %d" % bs)
print("Violation rule = %s" % str(viol_rule))
code_version = 'chemo_trustregion'

version = 'chemo_trustregion'
# Out:
# Algorithms = {'cart': None, 'linear': None, 'rf': None, 'mlp': None, 'gbm': None, 'svm': None}
# Bootstrap iterations = 0
# Violation rule = 0.5

# %% [markdown]
# ## Train candidate ML models and select models to embed

# %%
performance = opticl.train_ml_models(outcome_list, version)
if not os.path.exists('results'):
    os.makedirs('results')
performance.to_csv('results/%s_performance.csv' % (code_version))
# performance = pd.read_csv('results/%s_performance.csv' % (code_version))

print("\nPreparing model master")
if viol_rule == 'average':
    gr_method = 'average'
    max_viol = None
    print("Group method = %s" % (gr_method))
    gr_string = 'average'
else: 
    gr_method = 'violation'
    max_viol = float(viol_rule)
    print("Group method = %s (violation limit = %.2f)" % (gr_method, max_viol))
    gr_string = 'violation_%.2f' % max_viol
# Out:
# Learning a model for Neutro4
# No bootstrap - training on full training data
# training Neutro4 with cart
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = cart, metric = None
# saving... results/cart_Neutro4_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.0200432326421685
# Train R2: 0.3021467451768366
# -------------------testing evaluation-----------------------
# Test MSE: 0.019041832379617617
# Test R2: -0.27527754538206173
#
# training Neutro4 with linear
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = linear, metric = None
# saving... results/linear_Neutro4_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.02150490628718667
# Train R2: 0.251255068725447
# -------------------testing evaluation-----------------------
# Test MSE: 0.010468936836548906
# Test R2: 0.29886999289182714
#
# training Neutro4 with rf
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = rf_shallow, metric = None
# saving... results/rf_shallow_Neutro4_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.008644331282212685
# Train R2: 0.699026857156254
# -------------------testing evaluation-----------------------
# Test MSE: 0.013909708286150567
# Test R2: 0.06843321133683689
#
# training Neutro4 with mlp
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# saving... results/mlp_Neutro4_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.019554703510671564
# Train R2: 0.3191560595213606
# -------------------testing evaluation-----------------------
# Test MSE: 0.029035724847562984
# Test R2: -0.94459268277272
#
# training Neutro4 with gbm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = gbm, metric = None
# saving... results/gbm_Neutro4_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.009967677980082105
# Train R2: 0.6529513654002622
# -------------------testing evaluation-----------------------
# Test MSE: 0.01582395945637119
# Test R2: -0.05976881696253833
#
# training Neutro4 with svm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = svm, metric = None
# saving... results/svm_Neutro4_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.015239562519058432
# Train R2: 0.4693980509096459
# -------------------testing evaluation-----------------------
# Test MSE: 0.014746624030059207
# Test R2: 0.012382940842603829
#
# Learning a model for OTHER_34
# No bootstrap - training on full training data
# training OTHER_34 with cart
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = cart, metric = None
# saving... results/cart_OTHER_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.0005458978203869483
# Train R2: 0.32648296842815094
# -------------------testing evaluation-----------------------
# Test MSE: 0.001372087818685206
# Test R2: -0.03647457853835068
#
# training OTHER_34 with linear
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = linear, metric = None
# saving... results/linear_OTHER_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.0007181500983827528
# Train R2: 0.11396179940243745
# -------------------testing evaluation-----------------------
# Test MSE: 0.0012392653246078114
# Test R2: 0.06385947930730429
#
# training OTHER_34 with rf
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = rf_shallow, metric = None
# saving... results/rf_shallow_OTHER_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.00029283409736989
# Train R2: 0.63870756643837
# -------------------testing evaluation-----------------------
# Test MSE: 0.001192332927194185
# Test R2: 0.09931219316908602
#
# training OTHER_34 with mlp
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# saving... results/mlp_OTHER_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.0006118209935161415
# Train R2: 0.24514837023118607
# -------------------testing evaluation-----------------------
# Test MSE: 0.0018174531700553102
# Test R2: -0.3729033832917139
#
# training OTHER_34 with gbm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = gbm, metric = None
# saving... results/gbm_OTHER_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.0003146887188655596
# Train R2: 0.6117438028068243
# -------------------testing evaluation-----------------------
# Test MSE: 0.0011857907941699567
# Test R2: 0.10425411778694782
#
# training OTHER_34 with svm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = svm, metric = None
# saving... results/svm_OTHER_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.00046229989731508785
# Train R2: 0.42962429431404814
# -------------------testing evaluation-----------------------
# Test MSE: 0.001202214710173927
# Test R2: 0.09184749833712536
#
# Learning a model for GINONV_34
# No bootstrap - training on full training data
# training GINONV_34 with cart
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = cart, metric = None
# saving... results/cart_GINONV_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.003570372100539148
# Train R2: 0.3708147217491077
# -------------------testing evaluation-----------------------
# Test MSE: 0.00747259997732989
# Test R2: -0.010506037902876297
#
# training GINONV_34 with linear
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = linear, metric = None
# saving... results/linear_GINONV_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.00405709203765725
# Train R2: 0.2850429841143478
# -------------------testing evaluation-----------------------
# Test MSE: 0.005834965634277023
# Test R2: 0.21094826134402922
#
# training GINONV_34 with rf
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = rf_shallow, metric = None
# saving... results/rf_shallow_GINONV_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.002718863219937887
# Train R2: 0.520871028735516
# -------------------testing evaluation-----------------------
# Test MSE: 0.005472237611392356
# Test R2: 0.25999930895175904
#
# training GINONV_34 with mlp
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# saving... results/mlp_GINONV_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.00507020551807911
# Train R2: 0.10650806698828652
# -------------------testing evaluation-----------------------
# Test MSE: 0.007953144059667893
# Test R2: -0.07548913590815176
#
# training GINONV_34 with gbm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = gbm, metric = None
# saving... results/gbm_GINONV_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.00378535194115928
# Train R2: 0.3329301127979888
# -------------------testing evaluation-----------------------
# Test MSE: 0.005456758042418673
# Test R2: 0.26209258277338676
#
# training GINONV_34 with svm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = svm, metric = None
# saving... results/svm_GINONV_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.0030894799088936834
# Train R2: 0.4555594707245556
# -------------------testing evaluation-----------------------
# Test MSE: 0.006913531385154724
# Test R2: 0.06509578605515276
#
# Learning a model for CONSTITUTIONAL_34
# No bootstrap - training on full training data
# training CONSTITUTIONAL_34 with cart
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = cart, metric = None
# saving... results/cart_CONSTITUTIONAL_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.00412072092359786
# Train R2: 0.3285378753035809
# -------------------testing evaluation-----------------------
# Test MSE: 0.004672793752111623
# Test R2: 0.09240001827853905
#
# training CONSTITUTIONAL_34 with linear
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = linear, metric = None
# saving... results/linear_CONSTITUTIONAL_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.006136937247891557
# Train R2: -2.220446049250313e-16
# -------------------testing evaluation-----------------------
# Test MSE: 0.005148516798390247
# Test R2: 0.0
#
# training CONSTITUTIONAL_34 with rf
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = rf_shallow, metric = None
# saving... results/rf_shallow_CONSTITUTIONAL_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.004003596640796081
# Train R2: 0.3476230114343143
# -------------------testing evaluation-----------------------
# Test MSE: 0.0050072633105977425
# Test R2: 0.0274357632156641
#
# training CONSTITUTIONAL_34 with mlp
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# saving... results/mlp_CONSTITUTIONAL_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.004769317198473315
# Train R2: 0.22285058395995638
# -------------------testing evaluation-----------------------
# Test MSE: 0.0073329177375421615
# Test R2: -0.4242777142797509
#
# training CONSTITUTIONAL_34 with gbm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = gbm, metric = None
# saving... results/gbm_CONSTITUTIONAL_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.004464200844505084
# Train R2: 0.27256860153836004
# -------------------testing evaluation-----------------------
# Test MSE: 0.0044452807034121855
# Test R2: 0.13659003602706266
#
# training CONSTITUTIONAL_34 with svm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = svm, metric = None
# saving... results/svm_CONSTITUTIONAL_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.0035999366870118053
# Train R2: 0.41339848500999077
# -------------------testing evaluation-----------------------
# Test MSE: 0.006989391357372957
# Test R2: -0.3575543464397912
#
# Learning a model for INFECTION_34
# No bootstrap - training on full training data
# training INFECTION_34 with cart
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = cart, metric = None
# saving... results/cart_INFECTION_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.004538324446858574
# Train R2: 0.40135738098223295
# -------------------testing evaluation-----------------------
# Test MSE: 0.004652441232304495
# Test R2: -0.5993911138495682
#
# training INFECTION_34 with linear
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = linear, metric = None
# saving... results/linear_INFECTION_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.006790602990095867
# Train R2: 0.10426316886295772
# -------------------testing evaluation-----------------------
# Test MSE: 0.0025863956246243583
# Test R2: 0.11086288415628409
#
# training INFECTION_34 with rf
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = rf_shallow, metric = None
# saving... results/rf_shallow_INFECTION_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.0025581255505708654
# Train R2: 0.6625620320226231
# -------------------testing evaluation-----------------------
# Test MSE: 0.0036096248058588415
# Test R2: -0.24089731617350552
#
# training INFECTION_34 with mlp
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# saving... results/mlp_INFECTION_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.005423309603909615
# Train R2: 0.2846205018955901
# -------------------testing evaluation-----------------------
# Test MSE: 0.012331995908312212
# Test R2: -3.2394269345803313
#
# training INFECTION_34 with gbm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = gbm, metric = None
# saving... results/gbm_INFECTION_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.005818431746700228
# Train R2: 0.23250061554506363
# -------------------testing evaluation-----------------------
# Test MSE: 0.0028000453795308878
# Test R2: 0.03741552557366268
#
# training INFECTION_34 with svm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = svm, metric = None
# saving... results/svm_INFECTION_34_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.002444928165115486
# Train R2: 0.677493705614598
# -------------------testing evaluation-----------------------
# Test MSE: 0.0034007220183838506
# Test R2: -0.16908184441086527
#
# Learning a model for DLT_PROP
# No bootstrap - training on full training data
# training DLT_PROP with cart
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = cart, metric = None
# saving... results/cart_DLT_PROP_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.018582523885505287
# Train R2: 0.36334158748639156
# -------------------testing evaluation-----------------------
# Test MSE: 0.023935386829786846
# Test R2: 0.2723729839977369
#
# training DLT_PROP with linear
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = linear, metric = None
# saving... results/linear_DLT_PROP_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.024609788630514638
# Train R2: 0.1568406391760243
# -------------------testing evaluation-----------------------
# Test MSE: 0.02830775991392976
# Test R2: 0.13945443947251135
#
# training DLT_PROP with rf
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = rf_shallow, metric = None
# saving... results/rf_shallow_DLT_PROP_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.013322680881295186
# Train R2: 0.5435497937432003
# -------------------testing evaluation-----------------------
# Test MSE: 0.025273454578621846
# Test R2: 0.23169621323078016
#
# training DLT_PROP with mlp
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# saving... results/mlp_DLT_PROP_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.017845154702991202
# Train R2: 0.38860469469768144
# -------------------testing evaluation-----------------------
# Test MSE: 0.0532084226217681
# Test R2: -0.6175166106061722
#
# training DLT_PROP with gbm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = gbm, metric = None
# saving... results/gbm_DLT_PROP_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.009810378978517234
# Train R2: 0.6638852534185873
# -------------------testing evaluation-----------------------
# Test MSE: 0.023073972211390237
# Test R2: 0.2985596737212819
#
# training DLT_PROP with svm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = svm, metric = None
# saving... results/svm_DLT_PROP_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.017804299894139175
# Train R2: 0.3900044269357531
# -------------------testing evaluation-----------------------
# Test MSE: 0.03826148913697501
# Test R2: -0.16313529279978045
#
# Learning a model for OS
# No bootstrap - training on full training data
# training OS with cart
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = cart, metric = None
# saving... results/cart_OS_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 2.677540495706479
# Train R2: 0.6245307850448949
# -------------------testing evaluation-----------------------
# Test MSE: 14.39376716117995
# Test R2: 0.2610949348332674
#
# training OS with linear
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = linear, metric = None
# saving... results/linear_OS_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 3.9758104095259426
# Train R2: 0.44247550478927067
# -------------------testing evaluation-----------------------
# Test MSE: 12.836334118654706
# Test R2: 0.3410458712971861
#
# training OS with rf
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = rf_shallow, metric = None
# saving... results/rf_shallow_OS_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 2.5598351472863423
# Train R2: 0.641036505439486
# -------------------testing evaluation-----------------------
# Test MSE: 13.488176012634048
# Test R2: 0.3075835211177125
#
# training OS with mlp
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = mlp, metric = None
# saving... results/mlp_OS_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 0.5728318489611465
# Train R2: 0.9196722794760297
# -------------------testing evaluation-----------------------
# Test MSE: 65.24223012231057
# Test R2: -2.3492145426782733
#
# training OS with gbm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = gbm, metric = None
# saving... results/gbm_OS_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 2.1451593044353072
# Train R2: 0.6991861444181648
# -------------------testing evaluation-----------------------
# Test MSE: 13.878655689715464
# Test R2: 0.28753821900817933
#
# training OS with svm
# ------------- Initialize grid  ----------------
# ------------- Running model  ----------------
# Algorithm = svm, metric = None
# saving... results/svm_OS_trained.pkl
# ------------- Model evaluation  ----------------
# -------------------training evaluation-----------------------
# Train MSE: 3.5332490706905664
# Train R2: 0.5045355030333514
# -------------------testing evaluation-----------------------
# Test MSE: 11.544950348970474
# Test R2: 0.4073391493395945
#
# Saving the performance...
# Done!
#
# Preparing model master
# Group method = violation (violation limit = 0.50)

# %% [markdown]
# ## Formulate + solve optimization problem

# %% [markdown]
# Define the basic conceptual model for the chemo optimization problem, without embedded constraints and objective terms.

# %%
def init_conceptual_model(pt, contex_vars):
    model = ConcreteModel('chemo')

    N = list(pt.keys())
    ########### STEP 1: Define Decision Variables ###########
    # Create x variable, and initialize empty y for outcome values
    model.x = Var(N,domain=NonNegativeReals)

    # Restrict some x to be binary
    x_binary = [i for i in N if '_Ind' in i]
    for i in x_binary:
        model.x[i].domain = Binary

    ########### STEP 2: Define Objective function ###########
        def obj_function(model):
            return 0
    model.OBJ = Objective(rule=obj_function, sense=minimize)

    ###### STEP 3: Add (optionally) any known constraints #####
    def constraint_rule1(model):
        return sum(model.x[i] for i in x_binary) <= 3
    model.Constraint1 = Constraint(rule=constraint_rule1)
    
    ###### STEP 4: Fix (optionally) any non-optimization variables #####
    def constraint_rule2(model, i):
        return model.x[i] == pt[i]
    model.Constraint2 = Constraint(contex_vars, rule=constraint_rule2)

    return model

# %% [markdown]
# Select a test sample to optimize (i.e. a cohort of patients treated in 2008 or later), given as a row number of the test set.

# %% [markdown]
# Specify **global** trust region data and clustering model (if relevant). This will force the solution to lie within the convex hull of the datapoints given in 'data'. It will only enforce the convex hull condition on the features that appear in 'data': features not in the trust region dataset will not be constrained by the convex hull.
#
# In this case, we enforce the trust region *only* on the treatment features. We do not apply it to the contextual features.

# %%
infeas_ids = []
for patient_ID in datasets_test['OS'][0].index:
    print("\nPatient %d" % patient_ID)
    pt = datasets_test['OS'][0].loc[patient_ID, :]
    features = pt.keys()
    var_fts = [i for i in gi.T_cols if i in features]
    context_fts = [i for i in gi.X_cols if i in features]
    
    tr_data = datasets_train['OS'][0][var_fts]
    trust_region_specs = {'data': tr_data,
                          'clustering_model':None,
                          'enlargement':[0]}

    mm = opticl.initialize_model_master(outcome_list)
    mm.loc[outcomes,'group_method'] = gr_method
    mm.loc[outcomes,'max_violation'] = max_viol
    mm.loc[outcomes, 'trust_region'] = False
    mm.loc[outcomes, 'var_features'] = [var_fts]
    mm.loc[outcomes, 'contex_features'] = [{i:pt[i] for i in context_fts}]
    model_master = opticl.model_selection(mm, performance)
    
    conceptual_model = init_conceptual_model(pt, [i for i in gi.X_cols if i in pt.keys()])
    final_model = opticl.optimization_MIP(conceptual_model, model_master, trust_region_specs)
    opt = SolverFactory('glpk')
    print('Solving...')
    results = opt.solve(final_model) 
    print('Done!')
    print(results.solver.termination_condition)
    try:
        print('Objective = %.1f' % value(final_model.OBJ))
    except:
        print('Infeasible')
        infeas_idsids.append(patient_ID)
# Out:
# Patient 0
#                                                                model  \
# Neutro4            {'results/gbm/chemo_trustregion_Neutro4_model....
# OTHER_34           {'results/gbm/chemo_trustregion_OTHER_34_model...
# GINONV_34          {'results/cart/chemo_trustregion_GINONV_34_mod...
# CONSTITUTIONAL_34  {'results/cart/chemo_trustregion_CONSTITUTIONA...
# INFECTION_34       {'results/linear/chemo_trustregion_INFECTION_3...
# DLT_PROP           {'results/gbm/chemo_trustregion_DLT_PROP_model...
# OS                 {'results/gbm/chemo_trustregion_OS_model.csv':...
#
#                          task objective    lb         ub  \
# Neutro4            continuous         0  None       0.15
# OTHER_34           continuous         0  None   0.100811
# GINONV_34          continuous         0  None      0.106
# CONSTITUTIONAL_34  continuous         0  None  0.0818182
# INFECTION_34       continuous         0  None      0.075
# DLT_PROP           continuous         0  None   0.637304
# OS                 continuous        -1  None       None
#
#                                                             features  \
# Neutro4            Index(['Asia', 'N_Patient', 'FRAC_MALE', 'AGE_...
# OTHER_34           Index(['Asia', 'N_Patient', 'FRAC_MALE', 'AGE_...
# GINONV_34          Index(['Asia', 'N_Patient', 'FRAC_MALE', 'AGE_...
# CONSTITUTIONAL_34  Index(['Asia', 'N_Patient', 'FRAC_MALE', 'AGE_...
# INFECTION_34       Index(['Asia', 'N_Patient', 'FRAC_MALE', 'AGE_...
# DLT_PROP           Index(['Asia', 'N_Patient', 'FRAC_MALE', 'AGE_...
# OS                 Index(['Asia', 'N_Patient', 'FRAC_MALE', 'AGE_...
#
#                                                         var_features  \
# Neutro4            [Capecitabine_Ind, Carboplatin_Ind, Cisplatin_...
# OTHER_34           [Capecitabine_Ind, Carboplatin_Ind, Cisplatin_...
# GINONV_34          [Capecitabine_Ind, Carboplatin_Ind, Cisplatin_...
# CONSTITUTIONAL_34  [Capecitabine_Ind, Carboplatin_Ind, Cisplatin_...
# INFECTION_34       [Capecitabine_Ind, Carboplatin_Ind, Cisplatin_...
# DLT_PROP           [Capecitabine_Ind, Carboplatin_Ind, Cisplatin_...
# OS                 [Capecitabine_Ind, Carboplatin_Ind, Cisplatin_...
#
#                                                      contex_features  \
# Neutro4            {'Asia': 0.0, 'N_Patient': 26.0, 'FRAC_MALE': ...
# OTHER_34           {'Asia': 0.0, 'N_Patient': 26.0, 'FRAC_MALE': ...
# GINONV_34          {'Asia': 0.0, 'N_Patient': 26.0, 'FRAC_MALE': ...
# CONSTITUTIONAL_34  {'Asia': 0.0, 'N_Patient': 26.0, 'FRAC_MALE': ...
# INFECTION_34       {'Asia': 0.0, 'N_Patient': 26.0, 'FRAC_MALE': ...
# DLT_PROP           {'Asia': 0.0, 'N_Patient': 26.0, 'FRAC_MALE': ...
# OS                 {'Asia': 0.0, 'N_Patient': 26.0, 'FRAC_MALE': ...
#
#                   group_models group_method ensemble_weights max_violation  \
# Neutro4                  False    violation             None           0.5
# OTHER_34                 False    violation             None           0.5
# GINONV_34                False    violation             None           0.5
# CONSTITUTIONAL_34        False    violation             None           0.5
# INFECTION_34             False    violation             None           0.5
# DLT_PROP                 False    violation             None           0.5
# OS                       False    violation             None           0.5
#
#                   trust_region  \
# Neutro4                  False
# OTHER_34                 False
# GINONV_34                False
# CONSTITUTIONAL_34        False
# INFECTION_34             False
# DLT_PROP                 False
# OS                       False
#
#                                                       dataset_path  \
# Neutro4                      processed-data/data_train_Neutro4.csv
# OTHER_34                    processed-data/data_train_OTHER_34.csv
# GINONV_34                  processed-data/data_train_GINONV_34.csv
# CONSTITUTIONAL_34  processed-data/data_train_CONSTITUTIONAL_34.csv
# INFECTION_34            processed-data/data_train_INFECTION_34.csv
# DLT_PROP                    processed-data/data_train_DLT_PROP.csv
# OS                                processed-data/data_train_OS.csv
#
#                   clustering_model enlargement SCM_counterfactuals
# Neutro4                       None         [0]                None
# OTHER_34                      None         [0]                None
# GINONV_34                     None         [0]                None
# CONSTITUTIONAL_34             None         [0]                None
# INFECTION_34                  None         [0]                None
# DLT_PROP                      None         [0]                None
# OS                            None         [0]                None
# Embedding constraints for Neutro4
# Adding single model.
# Embedding constraints for OTHER_34
# Adding single model.
# Embedding constraints for GINONV_34
# Adding single model.
# Embedding constraints for CONSTITUTIONAL_34
# Adding single model.
# Embedding constraints for INFECTION_34
# Adding single model.
# Embedding constraints for DLT_PROP
# Adding single model.
# Embedding objective function for OS
# Adding single model.
# Solving...
# WARNING: Could not locate the 'glpsol' executable, which is required for
#     solver 'glpk'
# ---------------------------------------------------------------------------
# ApplicationError                          Traceback (most recent call last)
# <ipython-input-14-4420648501ac> in <module>
#      24     opt = SolverFactory('glpk')
#      25     print('Solving...')
# ---> 26     results = opt.solve(final_model)
#      27     print('Done!')
#      28     print(results.solver.termination_condition)
#
# ~/.local/lib/python3.7/site-packages/pyomo/opt/base/solvers.py in solve(self, *args, **kwds)
#     511         """ Solve the problem """
#     512
# --> 513         self.available(exception_flag=True)
#     514         #
#     515         # If the inputs are models, then validate that they have been
#
# ~/.local/lib/python3.7/site-packages/pyomo/opt/solver/shellcmd.py in available(self, exception_flag)
#     127             if exception_flag:
#     128                 msg = "No executable found for solver '%s'"
# --> 129                 raise ApplicationError(msg % self.name)
#     130             return False
#     131         return True
#
# ApplicationError: No executable found for solver 'glpk'

# %% [markdown]
# ## Inspect the solution

# %% [markdown]
# What were the contextual features of this patient?

# %%
for i in context_fts:
    val = value(final_model.x[i])
    print("%s: %.3f" % (i, val))
# Out:
# Asia: 1.000
# N_Patient: 14.000
# FRAC_MALE: 0.500
# AGE_MED: 45.900
# Prior_Palliative_Chemo: 0.000
# Primary_Stomach: 1.000
# Primary_GEJ: 0.000
# ECOG_MEAN: 0.905

# %% [markdown]
# What drugs are recommended, and in what doses (average and instantaneous)?

# %%
for i in var_fts:
    val = value(final_model.x[i])
    if val > 1e-6:
        print("%s: %.3f" % (i, val))
# Out:
# Fluorouracil_Ind: 1.000
# Leucovorin_Ind: 1.000
# Paclitaxel_Ind: 1.000
# Fluorouracil_Avg: 1500.000
# Leucovorin_Avg: 375.000
# Paclitaxel_Avg: 43.750
# Fluorouracil_Inst: 2000.000
# Leucovorin_Inst: 500.000
# Paclitaxel_Inst: 175.000

# %%
## What is the predicted value of each toxicity and objective?

# %%
for i in outcome_list:
    val = value(final_model.y[i])
    try: # print constraints
        print("%s: %.3f (limit = %.3f)" % (i, val, tox_summary.loc[i,ub_quantile]))
    except: # no bound for objective
        print("%s: %.3f" % (i, val))
# Out:
# Neutro4: 0.079 (limit = 0.150)
# OTHER_34: 0.091 (limit = 0.101)
# GINONV_34: 0.020 (limit = 0.106)
# CONSTITUTIONAL_34: 0.060 (limit = 0.082)
# INFECTION_34: 0.048 (limit = 0.075)
# DLT_PROP: 0.527 (limit = 0.637)
# OS: 11.306
